# %% [markdown]
# ### SETN 2026
# We will use a new dataset with a new task.

# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import eda_functions
from datasets import load_dataset

# %%
ds = load_dataset("FinanceMTEB/ESG")

# %%
print(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'label_text'],
#         num_rows: 3000
#     })
#     test: Dataset({
#         features: ['text', 'label', 'label_text'],
#         num_rows: 1000
#     })
# })

# %%
# Αποθήκευση ξεχωριστών dataset
train_ds = ds['train']
test_ds = ds['test']

# Έλεγχος
print(train_ds)
print(test_ds)
# Out:
# Dataset({
#     features: ['text', 'label', 'label_text'],
#     num_rows: 3000
# })
# Dataset({
#     features: ['text', 'label', 'label_text'],
#     num_rows: 1000
# })

# %%
train = pd.DataFrame(train_ds)
test = pd.DataFrame(test_ds)

print(train.head())
print(test.head())
# Out:
#                                                 text  label     label_text
# 0  This explains the increase in high-risk events...      3         social
# 1  Focusing on shared value creation in 2019 allo...      3         social
# 2  We included information on our policy and lobb...      1     governance
# 3  As of December 31, 2011, the project was appro...      2        non-esg
# 4  Independent lines of evidence continue to indi...      0  environmental
#                                                 text  label     label_text
# 0  Our fiscal year ends on the last Saturday of N...      2        non-esg
# 1  In general, pest control customers sign an ini...      2        non-esg
# 2  Despite these challenges, we’re already runnin...      0  environmental
# 3  For 2010, 56 percent of our consolidated molyb...      2        non-esg
# 4  Of these amounts, $201, $170, $167, $258, $214...      2        non-esg

# %%
print(train.nunique())
# Out:
# text          3000
# label            4
# label_text       4
# dtype: int64

# %%
fig = eda_functions.histogram(train, 'label_text')

# %%
non_esg = train[train['label_text'] == 'non-esg']
others = train[train['label_text'] != 'non-esg']

non_esg_downsampled = non_esg.sample(n=706, random_state=42)

train_df = pd.concat([non_esg_downsampled, others]).sample(frac=1, random_state=42)  # shuffle

print(train_df['label_text'].value_counts())
# Out:
# label_text
# social           802
# non-esg          706
# environmental    609
# governance        86
# Name: count, dtype: int64

# %%
X_train = train_df.text
y_train = train_df.label
X_test = test.text
y_test = test.label
