# %% [markdown]
# # Impact Length
#
#
# ### Description of the Notebook
# On this notebook we will focus on impact length. We will do a baseline of predicting impact length with machine learning models. As a multi-classification problem and as we have an imbalanced dataset, we will have as a metric the f1-score and auc-pr. The models will be Logistic Regression, Random Forest, Support Vector Machine, Naive Bayes and XGBoost. Our goal is to find the best combination of hyperparameters with the highest metrics.

# %%
import models
import pandas as pd
import importlib
importlib.reload(models)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# <module 'models' from 'c:\\Users\\USER\\OneDrive\\Υπολογιστής\\Data Science\\Thesis\\coding\\models.py'>

# %%
train_df = pd.read_csv('datasets/update_datasets/train_df.csv')
test_df = pd.read_csv('datasets/update_datasets/test_df.csv')

# %%
X_train = train_df.news_content
y_train = train_df.impact_length
X_test = test_df.news_content
y_test = test_df.impact_length

# %%
f1_scores, auc_pr,  best_params_list = models.run(X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test, model_name='logistic_regression', num_runs=5)
# Out:
# Run 1: F1 Score = 0.4798, AUC-PR = 0.4896
# Best Hyperparameters: {'logistic_regression__C': 0.02, 'logistic_regression__class_weight': 'balanced', 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'saga', 'tfidf__lowercase': True, 'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]}
#
# Run 2: F1 Score = 0.4339, AUC-PR = 0.5037
# Best Hyperparameters: {'logistic_regression__C': 0.01, 'logistic_regression__class_weight': 'balanced', 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'saga', 'tfidf__lowercase': True, 'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 2), 'tfidf__stop_words': None}
#
# Run 3: F1 Score = 0.4879, AUC-PR = 0.5215
# Best Hyperparameters: {'logistic_regression__C': 0.01, 'logistic_regression__class_weight': 'balanced', 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'lbfgs', 'tfidf__lowercase': True, 'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 2), 'tfidf__stop_words': None}
#
# Run 4: F1 Score = 0.4639, AUC-PR = 0.4983
# Best Hyperparameters: {'logistic_regression__C': 0.02, 'logistic_regression__class_weight': 'balanced', 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'saga', 'tfidf__lowercase': True, 'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 2), 'tfidf__stop_words': ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]}
#
# Run 5: F1 Score = 0.4970, AUC-PR = 0.5210
# Best Hyperparameters: {'logistic_regression__C': 0.02, 'logistic_regression__class_weight': 'balanced', 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'lbfgs', 'tfidf__lowercase': True, 'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 2), 'tfidf__stop_words': None}
#
#
# Mean F1 Score: 0.4725 ± 0.0222
# Mean AUC-PR: 0.5068 ± 0.0126

# %%
f1_scores_rf, auc_pr_rf,  best_params_list_rf = models.run(X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test, model_name='random_forest', num_runs=5)
# Out:
# Run 1: F1 Score = 0.3959, AUC-PR = 0.4453
# Best Hyperparameters: {'random_forest__bootstrap': True, 'random_forest__class_weight': 'balanced', 'random_forest__max_depth': 15, 'random_forest__min_samples_leaf': 4, 'random_forest__min_samples_split': 10, 'random_forest__n_estimators': 50, 'tfidf__lowercase': True, 'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 2), 'tfidf__stop_words': ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]}
#
# Run 2: F1 Score = 0.4102, AUC-PR = 0.4416
# Best Hyperparameters: {'random_forest__bootstrap': True, 'random_forest__class_weight': 'balanced', 'random_forest__max_depth': 10, 'random_forest__min_samples_leaf': 4, 'random_forest__min_samples_split': 2, 'random_forest__n_estimators': 50, 'tfidf__lowercase': False, 'tfidf__max_features': 500, 'tfidf__ngram_range': (1, 2), 'tfidf__stop_words': None}
#
# Run 3: F1 Score = 0.4589, AUC-PR = 0.4797
# Best Hyperparameters: {'random_forest__bootstrap': True, 'random_forest__class_weight': 'balanced', 'random_forest__max_depth': 5, 'random_forest__min_samples_leaf': 4, 'random_forest__min_samples_split': 2, 'random_forest__n_estimators': 100, 'tfidf__lowercase': False, 'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': None}
#
# Run 4: F1 Score = 0.3850, AUC-PR = 0.4647
# Best Hyperparameters: {'random_forest__bootstrap': True, 'random_forest__class_weight': 'balanced', 'random_forest__max_depth': 5, 'random_forest__min_samples_leaf': 4, 'random_forest__min_samples_split': 10, 'random_forest__n_estimators': 100, 'tfidf__lowercase': True, 'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': None}
#
# Run 5: F1 Score = 0.4226, AUC-PR = 0.4747
# Best Hyperparameters: {'random_forest__bootstrap': True, 'random_forest__class_weight': 'balanced', 'random_forest__max_depth': 15, 'random_forest__min_samples_leaf': 4, 'random_forest__min_samples_split': 10, 'random_forest__n_estimators': 100, 'tfidf__lowercase': True, 'tfidf__max_features': 1000, 'tfidf__ngram_range': (1, 2), 'tfidf__stop_words': ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]}
#
#
# Mean F1 Score: 0.4145 ± 0.0256
# Mean AUC-PR: 0.4612 ± 0.0153

# %%
f1_scores_svm, auc_pr_svm,  best_params_list_svm = models.run(X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test, model_name='svm', num_runs=5)
# Out:
# Run 1: F1 Score = 0.3930, AUC-PR = 0.4690
# Best Hyperparameters: {'svm__C': 1, 'svm__class_weight': 'balanced', 'svm__gamma': 'scale', 'svm__kernel': 'linear', 'svm__probability': True, 'tfidf__lowercase': False, 'tfidf__max_features': 500, 'tfidf__ngram_range': (1, 2), 'tfidf__stop_words': None}
#
# Run 2: F1 Score = 0.3840, AUC-PR = 0.4531
# Best Hyperparameters: {'svm__C': 1, 'svm__class_weight': 'balanced', 'svm__gamma': 'scale', 'svm__kernel': 'linear', 'svm__probability': True, 'tfidf__lowercase': False, 'tfidf__max_features': 500, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]}
#
# Run 3: F1 Score = 0.4374, AUC-PR = 0.4862
# Best Hyperparameters: {'svm__C': 1, 'svm__class_weight': 'balanced', 'svm__gamma': 'scale', 'svm__kernel': 'linear', 'svm__probability': True, 'tfidf__lowercase': False, 'tfidf__max_features': 1000, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': None}
#
# Run 4: F1 Score = 0.4855, AUC-PR = 0.4463
# Best Hyperparameters: {'svm__C': 1, 'svm__class_weight': 'balanced', 'svm__gamma': 'scale', 'svm__kernel': 'linear', 'svm__probability': True, 'tfidf__lowercase': True, 'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]}
#
# Run 5: F1 Score = 0.4785, AUC-PR = 0.5451
# Best Hyperparameters: {'svm__C': 1, 'svm__class_weight': 'balanced', 'svm__gamma': 'scale', 'svm__kernel': 'linear', 'svm__probability': True, 'tfidf__lowercase': False, 'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': None}
#
#
# Mean F1 Score: 0.4357 ± 0.0420
# Mean AUC-PR: 0.4799 ± 0.0354

# %%
f1_scores_nb, auc_pr_nb,  best_params_list_nb = models.run(X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test, model_name='nb', num_runs=5)
# Out:
# Run 1: F1 Score = 0.3815, AUC-PR = 0.4554
# Best Hyperparameters: {'nb__alpha': 0.01, 'tfidf__lowercase': False, 'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]}
#
# Run 2: F1 Score = 0.4178, AUC-PR = 0.4362
# Best Hyperparameters: {'nb__alpha': 0.05, 'tfidf__lowercase': True, 'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 2), 'tfidf__stop_words': ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]}
#
# Run 3: F1 Score = 0.4605, AUC-PR = 0.4896
# Best Hyperparameters: {'nb__alpha': 0.01, 'tfidf__lowercase': True, 'tfidf__max_features': 1000, 'tfidf__ngram_range': (1, 2), 'tfidf__stop_words': None}
#
# Run 4: F1 Score = 0.3810, AUC-PR = 0.4659
# Best Hyperparameters: {'nb__alpha': 0.001, 'tfidf__lowercase': False, 'tfidf__max_features': 500, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': None}
#
# Run 5: F1 Score = 0.4430, AUC-PR = 0.4634
# Best Hyperparameters: {'nb__alpha': 0.05, 'tfidf__lowercase': False, 'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 2), 'tfidf__stop_words': ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]}
#
#
# Mean F1 Score: 0.4167 ± 0.0320
# Mean AUC-PR: 0.4621 ± 0.0172

# %%
f1_scores_xgb, auc_pr_rf,  best_params_list_xgb = models.run(X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test, model_name='xgboost', num_runs=5)
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [00:39:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Run 1: F1 Score = 0.3682, AUC-PR = 0.4123
# Best Hyperparameters: {'tfidf__lowercase': False, 'tfidf__max_features': 500, 'tfidf__ngram_range': (1, 2), 'tfidf__stop_words': None, 'xgboost__gamma': 0.01, 'xgboost__learning_rate': 0.05, 'xgboost__max_depth': 4, 'xgboost__n_estimators': 150, 'xgboost__subsample': 0.8}
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [01:57:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Run 2: F1 Score = 0.3857, AUC-PR = 0.4533
# Best Hyperparameters: {'tfidf__lowercase': False, 'tfidf__max_features': 1000, 'tfidf__ngram_range': (1, 2), 'tfidf__stop_words': None, 'xgboost__gamma': 0.01, 'xgboost__learning_rate': 0.05, 'xgboost__max_depth': 3, 'xgboost__n_estimators': 150, 'xgboost__subsample': 0.8}
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [02:43:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Run 3: F1 Score = 0.4069, AUC-PR = 0.4610
# Best Hyperparameters: {'tfidf__lowercase': True, 'tfidf__max_features': 1000, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"], 'xgboost__gamma': 0.01, 'xgboost__learning_rate': 0.05, 'xgboost__max_depth': 4, 'xgboost__n_estimators': 150, 'xgboost__subsample': 1.0}
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [03:29:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Run 4: F1 Score = 0.3663, AUC-PR = 0.4182
# Best Hyperparameters: {'tfidf__lowercase': False, 'tfidf__max_features': 500, 'tfidf__ngram_range': (1, 2), 'tfidf__stop_words': None, 'xgboost__gamma': 0.01, 'xgboost__learning_rate': 0.05, 'xgboost__max_depth': 4, 'xgboost__n_estimators': 150, 'xgboost__subsample': 1.0}
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [04:16:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Run 5: F1 Score = 0.4533, AUC-PR = 0.4589
# Best Hyperparameters: {'tfidf__lowercase': False, 'tfidf__max_features': 1000, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': None, 'xgboost__gamma': 0.01, 'xgboost__learning_rate': 0.05, 'xgboost__max_depth': 4, 'xgboost__n_estimators': 150, 'xgboost__subsample': 1.0}
#
#
# Mean F1 Score: 0.3961 ± 0.0321
# Mean AUC-PR: 0.4408 ± 0.0211

# %% [markdown]
# ### Grid to the best two models + preprocess

# %%
f1_scores_lr2, auc_pr_lr2,  best_params_list_lr2 = models.runs(X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test, model_name='logistic_regression', num_runs=5)
# Out:
# Run 1: F1 Score = 0.4411, AUC-PR = 0.4861
# Best Hyperparameters: {'logistic_regression__C': 0.01, 'logistic_regression__class_weight': 'balanced', 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'lbfgs', 'preprocessor__preprocess_type': 'lemmatization', 'tfidf__lowercase': True, 'tfidf__max_features': 1000, 'tfidf__ngram_range': (1, 2), 'tfidf__stop_words': ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]}
#
# Run 2: F1 Score = 0.4792, AUC-PR = 0.5222
# Best Hyperparameters: {'logistic_regression__C': 0.02, 'logistic_regression__class_weight': 'balanced', 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'lbfgs', 'preprocessor__preprocess_type': 'lemmatization', 'tfidf__lowercase': True, 'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 2), 'tfidf__stop_words': None}
#
# Run 3: F1 Score = 0.4452, AUC-PR = 0.5351
# Best Hyperparameters: {'logistic_regression__C': 0.02, 'logistic_regression__class_weight': 'balanced', 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'lbfgs', 'preprocessor__preprocess_type': 'lemmatization', 'tfidf__lowercase': True, 'tfidf__max_features': 3000, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]}
#
# Run 4: F1 Score = 0.5088, AUC-PR = 0.5324
# Best Hyperparameters: {'logistic_regression__C': 0.02, 'logistic_regression__class_weight': 'balanced', 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'saga', 'preprocessor__preprocess_type': 'lemmatization', 'tfidf__lowercase': True, 'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 2), 'tfidf__stop_words': None}
#
# Run 5: F1 Score = 0.4658, AUC-PR = 0.4887
# Best Hyperparameters: {'logistic_regression__C': 0.002, 'logistic_regression__class_weight': 'balanced', 'logistic_regression__penalty': 'l2', 'logistic_regression__solver': 'lbfgs', 'preprocessor__preprocess_type': 'lemmatization', 'tfidf__lowercase': True, 'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': None}
#
#
# Mean F1 Score: 0.4680 ± 0.0246
# Mean AUC-PR: 0.5129 ± 0.0213

# %%
f1_scores_svm2, auc_pr_svm2,  best_params_list_svm2 = models.runs(X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test, model_name='svm', num_runs=5)
# Out:
# Run 1: F1 Score = 0.4793, AUC-PR = 0.4882
# Best Hyperparameters: {'preprocessor__preprocess_type': 'lemmatization', 'svm__C': 1, 'svm__class_weight': 'balanced', 'svm__gamma': 'scale', 'svm__kernel': 'linear', 'svm__probability': True, 'tfidf__lowercase': True, 'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': None}
#
# Run 2: F1 Score = 0.4256, AUC-PR = 0.4773
# Best Hyperparameters: {'preprocessor__preprocess_type': 'lemmatization', 'svm__C': 1, 'svm__class_weight': 'balanced', 'svm__gamma': 'scale', 'svm__kernel': 'linear', 'svm__probability': True, 'tfidf__lowercase': False, 'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]}
#
# Run 3: F1 Score = 0.4109, AUC-PR = 0.5202
# Best Hyperparameters: {'preprocessor__preprocess_type': 'lemmatization', 'svm__C': 1, 'svm__class_weight': 'balanced', 'svm__gamma': 'scale', 'svm__kernel': 'linear', 'svm__probability': True, 'tfidf__lowercase': False, 'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]}
#
# Run 4: F1 Score = 0.4766, AUC-PR = 0.5018
# Best Hyperparameters: {'preprocessor__preprocess_type': 'lemmatization', 'svm__C': 1, 'svm__class_weight': 'balanced', 'svm__gamma': 'scale', 'svm__kernel': 'linear', 'svm__probability': True, 'tfidf__lowercase': False, 'tfidf__max_features': 2000, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]}
#
# Run 5: F1 Score = 0.4244, AUC-PR = 0.4690
# Best Hyperparameters: {'preprocessor__preprocess_type': 'stemming', 'svm__C': 1, 'svm__class_weight': 'balanced', 'svm__gamma': 'scale', 'svm__kernel': 'linear', 'svm__probability': True, 'tfidf__lowercase': True, 'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]}
#
#
# Mean F1 Score: 0.4434 ± 0.0287
# Mean AUC-PR: 0.4913 ± 0.0182

# %% [markdown]
# ### Running the best models with the best combination of hyperparameters in whole training set

# %%
X_train = train_df.news_content
y_train = train_df.impact_length
X_test = test_df.news_content
y_test = test_df.impact_length

# %% [markdown]
# Creation of an tfidf dataframe

# %%
importlib.reload(models)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# <module 'models' from 'c:\\Users\\USER\\OneDrive\\Υπολογιστής\\Data Science\\Thesis\\coding\\models.py'>

# %%
a, train_tfidf_df, test_tfidf_df = models.compute_tfidf_level(train_df, test_df, column = 'news_content', max_features=2000, ngram_range=(1, 2), preprocess_type='lemmatization')

# %% [markdown]
# The next step involves importing all the newly created attributes into the dataset and evaluating their impact on model performance. Specifically, the F1-scores and AUC values will be compared before and after the inclusion of these attributes in order to assess whether they contribute to improving the predictive power of the models.
#
# Let's first import all the new attributes.

# %%
train_esg = pd.read_csv('datasets/update_datasets/train_esg.csv')
test_esg = pd.read_csv('datasets/update_datasets/test_esg.csv')
train_sent = pd.read_csv('datasets/update_datasets/train_sent.csv')
test_sent = pd.read_csv('datasets/update_datasets/test_sent.csv')
train_esg_sent = pd.read_csv('datasets/update_datasets/train_esg_sent.csv')
test_esg_sent = pd.read_csv('datasets/update_datasets/test_esg_sent.csv')

# %%
train_tfidf_df.to_csv("datasets/update_datasets/train_tfidf_length.csv", index=False)
test_tfidf_df.to_csv("datasets/update_datasets/test_tfidf_length.csv", index=False)

# %% [markdown]
# #### Running the Model on the Entire Training Dataset and Evaluating on the Test Set

# %%
X_train = train_tfidf_df
X_test = test_tfidf_df
f1_score_tfidf, auc_pr_tfidf = models.best_model_length(X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)
print(f1_score_tfidf, auc_pr_tfidf)
# Out:
# 0.44662756598240466 0.5030040470271908

# %% [markdown]
# From this point onward, the newly created attributes will be incorporated into the base datasets (train and test sets) alongside the TF-IDF representations. The evaluation will be conducted using the best-performing model with its optimal hyperparameters to assess the impact on the scores.
#
# #### ESG Topics

# %%
X_train_esg = pd.concat([X_train, train_esg], axis=1)
X_test_esg = pd.concat([X_test, test_esg], axis=1)

# %%
f1_score_esg, auc_pr_esg = models.best_model_length(X_train=X_train_esg, y_train=y_train, X_test=X_test_esg, y_test=y_test)
print(f1_score_esg, auc_pr_esg)
# Out:
# 0.4873015873015873 0.49509973154688147

# %% [markdown]
# #### Sentiment Analysis

# %%
X_train_sent = pd.concat([X_train, train_sent], axis=1)
X_test_sent = pd.concat([X_test, test_sent], axis=1)

# %%
f1_score_sent, auc_pr_sent = models.best_model_length(X_train=X_train_sent, y_train=y_train, X_test=X_test_sent, y_test=y_test)
print(f1_score_sent, auc_pr_sent)
# Out:
# 0.43085183725309867 0.5067157559239924

# %% [markdown]
# #### ESG Topics + Sentiment Analysis

# %%
X_train_esg_sent = pd.concat([X_train, train_esg, train_sent], axis=1)
X_test_esg_sent = pd.concat([X_test, test_esg, test_sent], axis=1)

# %%
f1_score_esg_sent, auc_pr_esg_sent = models.best_model_length(X_train=X_train_esg_sent, y_train=y_train, X_test=X_test_esg_sent, y_test=y_test)
print(f1_score_esg_sent, auc_pr_esg_sent)
# Out:
# 0.45720092915214866 0.49426970939364195

# %% [markdown]
# ### Embeddings - 768 dimensions

# %%
train_768_esg = pd.read_csv('datasets/update_datasets/train_esg_embeddings.csv')
test_768_esg = pd.read_csv('datasets/update_datasets/test_esg_embeddings.csv')
train_768_sent = pd.read_csv('datasets/update_datasets/train_sent_embeddings.csv')
test_768_sent = pd.read_csv('datasets/update_datasets/test_sent_embeddings.csv')
train_768_esg_sent = pd.read_csv('datasets/update_datasets/train_esg_sent_embeddings.csv')
test_768_esg_sent = pd.read_csv('datasets/update_datasets/test_esg_sent_embeddings.csv')

# %% [markdown]
# #### ESG Topics

# %%
X_train_768_esg = pd.concat([X_train, train_768_esg], axis=1)
X_test_768_esg = pd.concat([X_test, test_768_esg], axis=1)

# %%
f1_score_768, auc_pr_768 = models.best_model_length(X_train=X_train_768_esg , y_train=y_train, X_test=X_test_768_esg, y_test=y_test)
print(f1_score_768, auc_pr_768)
# Out:
# 0.4083091787439613 0.44486207445321196
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# #### Sentiment Analysis

# %%
X_train_768_sent = pd.concat([X_train, train_768_sent], axis=1)
X_test_768_sent = pd.concat([X_test, test_768_sent], axis=1)

# %%
f1_score_768, auc_pr_768 = models.best_model_length(X_train=X_train_768_sent , y_train=y_train, X_test=X_test_768_sent, y_test=y_test)
print(f1_score_768, auc_pr_768)
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.4846310790019399 0.5073291909576396

# %% [markdown]
# #### ESG Topics + Sentiment Analysis

# %%
X_train_768_esg_sent = pd.concat([X_train, train_768_esg_sent], axis=1)
X_test_768_esg_sent = pd.concat([X_test, test_768_esg_sent], axis=1)

# %%
f1_score_768, auc_pr_768 = models.best_model_length(X_train=X_train_768_esg_sent , y_train=y_train, X_test=X_test_768_esg_sent, y_test=y_test)
print(f1_score_768, auc_pr_768)
# Out:
# 0.41532731096298453 0.4688602779307849
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
